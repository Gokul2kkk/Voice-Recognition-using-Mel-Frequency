# %%
from python_speech_features import mfcc
from python_speech_features import logfbank
from scipy.io.wavfile import read
import scipy.io.wavfile as wav
import matplotlib.pyplot as plt
import numpy as np
import pyaudio
import wave
import os
 #Harini   
print("HARINI S")
print("CB.EN.U4ECE17019")
print("Average mfcc values")
(rate,sig) = wav.read("C:/Users/HAR S/Desktop/AUDIO/1.wav")
mfcc_feat = mfcc(sig,rate)
fbank_feat = logfbank(sig,rate)
avg_mfcc = np.mean(mfcc_feat, axis = 0)
print avg_mfcc
(rate,sig) = wav.read("C:/Users/HAR S/Desktop/AUDIO/2.wav")
mfcc_feat = mfcc(sig,rate)
fbank_feat = logfbank(sig,rate)
avg_mfcc = np.mean(mfcc_feat, axis = 0)
print avg_mfcc
(rate,sig) = wav.read("C:/Users/HAR S/Desktop/AUDIO/3.wav")
mfcc_feat = mfcc(sig,rate)
fbank_feat = logfbank(sig,rate)
avg_mfcc = np.mean(mfcc_feat, axis = 0)
print avg_mfcc
(rate,sig) = wav.read("C:/Users/HAR S/Desktop/AUDIO/4.wav")
mfcc_feat = mfcc(sig,rate)
fbank_feat = logfbank(sig,rate)
avg_mfcc = np.mean(mfcc_feat, axis = 0)
print avg_mfcc
(rate,sig) = wav.read("C:/Users/HAR S/Desktop/AUDIO/5.wav")
mfcc_feat = mfcc(sig,rate)
fbank_feat = logfbank(sig,rate)
avg_mfcc = np.mean(mfcc_feat, axis = 0)
print avg_mfcc
#Gokul14
print("GOKUL S")
print("CB.EN.U4ECE17014")
print("Average mfcc values")
(rate,sig) = wav.read("C:/Users/HAR S/Desktop/AUDIO/6.wav")
mfcc_feat = mfcc(sig,rate)
fbank_feat = logfbank(sig,rate)
avg_mfcc = np.mean(mfcc_feat, axis = 0)
print avg_mfcc
(rate,sig) = wav.read("C:/Users/HAR S/Desktop/AUDIO/7.wav")
mfcc_feat = mfcc(sig,rate)
fbank_feat = logfbank(sig,rate)
avg_mfcc = np.mean(mfcc_feat, axis = 0)
print avg_mfcc
(rate,sig) = wav.read("C:/Users/HAR S/Desktop/AUDIO/8.wav")
mfcc_feat = mfcc(sig,rate)
fbank_feat = logfbank(sig,rate)
avg_mfcc = np.mean(mfcc_feat, axis = 0)
print avg_mfcc
(rate,sig) = wav.read("C:/Users/HAR S/Desktop/AUDIO/9.wav")
mfcc_feat = mfcc(sig,rate)
fbank_feat = logfbank(sig,rate)
avg_mfcc = np.mean(mfcc_feat, axis = 0)
print avg_mfcc
(rate,sig) = wav.read("C:/Users/HAR S/Desktop/AUDIO/10.wav")
mfcc_feat = mfcc(sig,rate)
fbank_feat = logfbank(sig,rate)
avg_mfcc = np.mean(mfcc_feat, axis = 0)
print avg_mfcc
#kukan
print("KUKAN S")
print("CB.EN.U4ECE17033")
print("Average mfcc values")
(rate,sig) = wav.read("C:/Users/HAR S/Desktop/AUDIO/16.wav")
mfcc_feat = mfcc(sig,rate)
fbank_feat = logfbank(sig,rate)
avg_mfcc = np.mean(mfcc_feat, axis = 0)
print avg_mfcc
(rate,sig) = wav.read("C:/Users/HAR S/Desktop/AUDIO/17.wav")
mfcc_feat = mfcc(sig,rate)
fbank_feat = logfbank(sig,rate)
avg_mfcc = np.mean(mfcc_feat, axis = 0)
print avg_mfcc
(rate,sig) = wav.read("C:/Users/HAR S/Desktop/AUDIO/18.wav")
mfcc_feat = mfcc(sig,rate)
fbank_feat = logfbank(sig,rate)
avg_mfcc = np.mean(mfcc_feat, axis = 0)
print avg_mfcc
(rate,sig) = wav.read("C:/Users/HAR S/Desktop/AUDIO/19.wav")
mfcc_feat = mfcc(sig,rate)
fbank_feat = logfbank(sig,rate)
avg_mfcc = np.mean(mfcc_feat, axis = 0)
print avg_mfcc
(rate,sig) = wav.read("C:/Users/HAR S/Desktop/AUDIO/20.wav")
mfcc_feat = mfcc(sig,rate)
fbank_feat = logfbank(sig,rate)
avg_mfcc = np.mean(mfcc_feat, axis = 0)
print avg_mfcc
#AUDIO INPUTTING
CHUNK = 1024
FORMAT = pyaudio.paInt16
CHANNELS = 2
RATE = 44100
RECORD_SECONDS = 8
WAVE_OUTPUT_FILENAME = "live.wav"
p = pyaudio.PyAudio()
stream = p.open(format=FORMAT,
                channels=CHANNELS,
                rate=RATE,
                input=True,
                frames_per_buffer=CHUNK)
print("* recording")
frames = []
for i in range(0, int(RATE / CHUNK * RECORD_SECONDS)):
    data = stream.read(CHUNK)
    
    frames.append(data)
print("* done recording")
stream.stop_stream()
stream.close()
p.terminate()
wf = wave.open(WAVE_OUTPUT_FILENAME, 'wb')
wf.setnchannels(CHANNELS)
wf.setsampwidth(p.get_sample_size(FORMAT))
wf.setframerate(RATE)
wf.writeframes(b''.join(frames))
sampling_rate, data=read("live.wav") # enter your filename
print sampling_rate
fs,x = read("live.wav")

#REPLAYING AND PLOTTING THE AUDIO
y=x[44100:]
plt.plot(y)

os.system(" start C:/Users/HAR S/Desktop/live.wav")
wf.close()

#CALCULATING LIVE MFCC
(rate,sig) = wav.read("C:/Users/HAR S/Desktop/live.wav")
mfcc_feat = mfcc(sig,rate)
fbank_feat = logfbank(sig,rate)
avg_mfcc = np.mean(mfcc_feat, axis = 0)
print avg_mfcc
